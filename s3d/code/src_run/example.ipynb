# %%
# %cd ./code/src_run
# !pwd
# Out:
# /mnt/c/Notebooks/Workout/code/src_run
# /mnt/c/Notebooks/Workout/code/src_run

# %%
from run_s3d import load_model, inference
# Out:
# /home/dlyko/miniconda3/envs/workout_2/lib/python3.11/site-packages/albumentations/check_version.py:147: UserWarning: Error fetching version info <urlopen error [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1016)>
#   data = fetch_version_info()

# %%
class_names = ['chest fly machine', 'leg raises', 'pull Up', 'push-up', 'squat', 'tricep dips']

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = load_model('../outputs/best_model.pth', device, class_names)
# Out:
# [INFO]: Freezing hidden layers...

# %%
saved_path = inference(model, device, class_names, str('my_video.mp4'), str('./saved'))
# Out:
# /mnt/c/Notebooks/Workout/code/src_run/run_s3d.py:40: UserWarning: Argument(s) 'always_apply' are not valid for transform Resize
#   A.Resize(resize_size[1], resize_size[0], always_apply=True),
# /mnt/c/Notebooks/Workout/code/src_run/run_s3d.py:41: UserWarning: Argument(s) 'always_apply' are not valid for transform CenterCrop
#   A.CenterCrop(crop_size[1], crop_size[0], always_apply=True),
# /mnt/c/Notebooks/Workout/code/src_run/run_s3d.py:42: UserWarning: Argument(s) 'always_apply' are not valid for transform Normalize
#   A.Normalize(
# Number of frames to consider for each prediction: 16
# Frame: 1, FPS: 1.6
# Frame: 2, FPS: 40.0
# Frame: 3, FPS: 53.3
# Frame: 4, FPS: 55.1
# Frame: 5, FPS: 51.4
# Frame: 6, FPS: 56.9
# Frame: 7, FPS: 53.4
# Frame: 8, FPS: 56.5
# Frame: 9, FPS: 57.7
# Frame: 10, FPS: 57.8
# Frame: 11, FPS: 56.0
# Frame: 12, FPS: 52.4
# Frame: 13, FPS: 53.2
# Frame: 14, FPS: 53.4
# Frame: 15, FPS: 55.4
# Frame: 16, FPS: 51.0
# Frame: 17, FPS: 55.3
# ...

# %%
saved_path
# Out:
# './saved/my_video.mp4'

# %%
# !pip freeze > requirements.txt
